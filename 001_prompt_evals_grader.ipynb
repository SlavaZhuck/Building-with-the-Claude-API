# %%
# Load env variables and create client
from dotenv import load_dotenv
from anthropic import Anthropic

load_dotenv()

client = Anthropic()
model = "claude-haiku-4-5"

# %%
# Helper functions
def add_user_message(messages, text):
    user_message = {"role": "user", "content": text}
    messages.append(user_message)


def add_assistant_message(messages, text):
    assistant_message = {"role": "assistant", "content": text}
    messages.append(assistant_message)


def chat(messages, system=None, temperature=1.0, stop_sequences=[]):
    params = {
        "model": model,
        "max_tokens": 1000,
        "messages": messages,
        # "temperature": temperature,
        "stop_sequences": stop_sequences,
    }

    if system:
        params["system"] = system

    message = client.messages.create(**params)
    return message.content[0].text

# %%
# Function to generate a new dataset
import json


def generate_dataset():
    prompt = """
Generate a evaluation dataset for a prompt evaluation. The dataset will be used to evaluate prompts
that generate Python, JSON, or Regex specifically for AWS-related tasks. Generate an array of JSON objects,
each representing task that requires Python, JSON, or a Regex to complete.

Example output:
```json
[
    {
        "task": "Description of task",
        "format": "json" or "python" or "regex"
    },
    ...additional
]
```

* Focus on tasks that can be solved by writing a single Python function, a single JSON object, or a regular expression.
* Focus on tasks that do not require writing much code

Please generate 3 objects.
"""

    messages = []
    add_user_message(messages, prompt)
    add_assistant_message(messages, "```json")
    text = chat(messages, stop_sequences=["```"])
    return json.loads(text)

# %%
# Generate the dataset and write it to 'dataset.json'
dataset = generate_dataset()
with open("dataset.json", "w") as f:
    json.dump(dataset, f, indent=2)

# %%
# Function to grade a test case + output using a model
def grade_by_model(test_case, output):
    eval_prompt = f"""
You are an expert AWS code reviewer. Your task is to evaluate the following AI-generated solution.

Original Task:
<task>
{test_case["task"]}
</task>

Solution to Evaluate:
<solution>
{output}
</solution>

Output Format
Provide your evaluation as a structured JSON object with the following fields, in this specific order:
- "strengths": An array of 1-3 key strengths
- "weaknesses": An array of 1-3 key areas for improvement
- "reasoning": A concise explanation of your overall assessment
- "score": A number between 1-10

Respond with JSON. Keep your response concise and direct.
Example response shape:
{{
    "strengths": string[],
    "weaknesses": string[],
    "reasoning": string,
    "score": number
}}
    """

    messages = []
    add_user_message(messages, eval_prompt)
    add_assistant_message(messages, "```json")
    eval_text = chat(messages, stop_sequences=["```"])
    return json.loads(eval_text)

# %%
# Passes a test case into Claude
def run_prompt(test_case):
    prompt = f"""
Please solve the following task:

{test_case["task"]}
"""

    messages = []
    add_user_message(messages, prompt)
    output = chat(messages)
    return output

# %%
# Function to execute a single test case and grade the output
def run_test_case(test_case):
    """Calls run_prompt, then grades the result"""
    output = run_prompt(test_case)

    model_grade = grade_by_model(test_case, output)
    score = model_grade["score"]
    reasoning = model_grade["reasoning"]

    return {
        "output": output,
        "test_case": test_case,
        "score": score,
        "reasoning": reasoning,
    }

# %%
from statistics import mean


def run_eval(dataset):
    """Loads the dataset and calls run_test_case with each case"""
    results = []

    for test_case in dataset:
        result = run_test_case(test_case)
        results.append(result)

    average_score = mean([result["score"] for result in results])
    print(f"Average score: {average_score}")

    return results

# %%
with open("dataset.json", "r") as f:
    dataset = json.load(f)

results = run_eval(dataset)
# Out:
# Average score: 6.333333333333333

# %%
print(json.dumps(results, indent=2))
# Out:
# [
#   {
#     "output": "# AWS S3 Bucket Name Parser\n\nHere are several solutions to extract the bucket name from an S3 URI:\n\n## Solution 1: Using String Methods (Simple)\n```python\ndef get_bucket_name(s3_uri):\n    \"\"\"Extract bucket name from S3 URI\"\"\"\n    # Remove 's3://' prefix and split by '/'\n    return s3_uri.replace('s3://', '').split('/')[0]\n\n# Test\nprint(get_bucket_name('s3://my-bucket/key/path'))  # Output: my-bucket\nprint(get_bucket_name('s3://another-bucket/file.txt'))  # Output: another-bucket\n```\n\n## Solution 2: Using Regular Expressions (Robust)\n```python\nimport re\n\ndef get_bucket_name(s3_uri):\n    \"\"\"Extract bucket name from S3 URI using regex\"\"\"\n    match = re.match(r's3://([^/]+)', s3_uri)\n    if match:\n        return match.group(1)\n    return None\n\n# Test\nprint(get_bucket_name('s3://my-bucket/key/path'))  # Output: my-bucket\nprint(get_bucket_name('invalid-uri'))  # Output: None\n```\n\n## Solution 3: Using urllib (Standard Library)\n```python\nfrom urllib.parse import urlparse\n\ndef get_bucket_name(s3_uri):\n    \"\"\"Extract bucket name from S3 URI using urllib\"\"\"\n    parsed = urlparse(s3_uri)\n    return parsed.netloc\n\n# Test\nprint(get_bucket_name('s3://my-bucket/key/path'))  # Output: my-bucket\n```\n\n## Solution 4: Using boto3 (AWS SDK)\n```python\nfrom urllib.parse import urlparse\n\ndef get_bucket_name(s3_uri):\n    \"\"\"Extract bucket name from S3 URI\"\"\"\n    # Parse S3 URI\n    parts = s3_uri.replace('s3://', '').split('/', 1)\n    return parts[0] if parts else None\n\n# Test\nprint(get_bucket_name('s3://my-bucket/key/path'))  # Output: my-bucket\n```\n\n## Comparison\n\n| Method | Pros | Cons |\n|--------|------|------|\n| **String Methods** | Simple, no imports | Less robust for edge cases |\n| **Regex** | Handles validation, edge cases | Requires `re` module |\n| **urllib** | Standard library, handles URLs well | Slightly verbose |\n| **boto3** | AWS-native | Requires boto3 installation |\n\n## Recommended Solution\n```python\nimport re\n\ndef parse_s3_bucket(s3_uri):\n    \"\"\"\n    Extract bucket name from S3 URI\n    \n    Args:\n        s3_uri (str): S3 URI in format 's3://bucket-name/key/path'\n    \n    Returns:\n        str: Bucket name or None if invalid\n    \"\"\"\n    match = re.match(r's3://([a-z0-9\\-\\.]+)', s3_uri)\n    return match.group(1) if match else None\n```\n\nChoose **Solution 2 (Regex)** for production code as it validates the bucket name format and handles edge cases gracefully.",
#     "test_case": {
#       "task": "Parse an AWS S3 bucket name from an S3 URI (s3://bucket-name/key/path) and extract only the bucket name",
#       "format": "regex"
#     },
#     "score": 6,
#     "reasoning": "The solution provides comprehensive coverage with multiple approaches and clear comparisons, which is valuable for AWS developers. However, it contains a significant accuracy issue (Solution 4 mislabeled), and the recommended regex pattern has a subtle but important limitation regarding case sensitivity that isn't addressed. The urllib solution (Solution 3) is actually simpler and more reliable than recommended, making the final recommendation questionable. These issues reduce confidence in the solution's correctness for production use."
#   },
#   {
#     "output": "# AWS IAM Policy Action Extractor\n\nHere's a comprehensive solution to extract all Actions from an AWS IAM policy JSON string:\n\n```python\nimport json\nfrom typing import List, Union\n\ndef extract_iam_policy_actions(policy_json: str) -> List[str]:\n    \"\"\"\n    Extracts all Actions from an AWS IAM policy JSON string.\n    \n    Args:\n        policy_json: A JSON string representing an AWS IAM policy\n        \n    Returns:\n        A list of all Actions specified in the policy (deduplicated and sorted)\n        \n    Raises:\n        json.JSONDecodeError: If the input is not valid JSON\n        TypeError: If the input is not a string\n    \"\"\"\n    if not isinstance(policy_json, str):\n        raise TypeError(\"Input must be a JSON string\")\n    \n    try:\n        policy = json.loads(policy_json)\n    except json.JSONDecodeError as e:\n        raise json.JSONDecodeError(f\"Invalid JSON: {e.msg}\", e.doc, e.pos)\n    \n    actions = set()\n    \n    # Helper function to recursively find all Actions\n    def extract_actions_recursive(obj):\n        if isinstance(obj, dict):\n            # Check if 'Action' key exists\n            if 'Action' in obj:\n                action_value = obj['Action']\n                # Action can be a string or a list of strings\n                if isinstance(action_value, str):\n                    actions.add(action_value)\n                elif isinstance(action_value, list):\n                    for action in action_value:\n                        if isinstance(action, str):\n                            actions.add(action)\n            \n            # Recursively check all values in the dictionary\n            for value in obj.values():\n                extract_actions_recursive(value)\n        \n        elif isinstance(obj, list):\n            # Recursively check all items in the list\n            for item in obj:\n                extract_actions_recursive(item)\n    \n    extract_actions_recursive(policy)\n    \n    # Return sorted list for consistent output\n    return sorted(list(actions))\n\n\n# Example usage and test cases\nif __name__ == \"__main__\":\n    # Test 1: Simple policy with single action\n    policy1 = {\n        \"Version\": \"2012-10-17\",\n        \"Statement\": [\n            {\n                \"Effect\": \"Allow\",\n                \"Action\": \"s3:GetObject\",\n                \"Resource\": \"arn:aws:s3:::my-bucket/*\"\n            }\n        ]\n    }\n    \n    print(\"Test 1 - Single Action:\")\n    print(extract_iam_policy_actions(json.dumps(policy1)))\n    # Output: ['s3:GetObject']\n    \n    # Test 2: Policy with multiple actions as list\n    policy2 = {\n        \"Version\": \"2012-10-17\",\n        \"Statement\": [\n            {\n                \"Effect\": \"Allow\",\n                \"Action\": [\n                    \"s3:GetObject\",\n                    \"s3:PutObject\",\n                    \"s3:DeleteObject\"\n                ],\n                \"Resource\": \"arn:aws:s3:::my-bucket/*\"\n            }\n        ]\n    }\n    \n    print(\"\\nTest 2 - Multiple Actions in list:\")\n    print(extract_iam_policy_actions(json.dumps(policy2)))\n    # Output: ['s3:DeleteObject', 's3:GetObject', 's3:PutObject']\n    \n    # Test 3: Policy with multiple statements\n    policy3 = {\n        \"Version\": \"2012-10-17\",\n        \"Statement\": [\n            {\n                \"Effect\": \"Allow\",\n                \"Action\": [\"s3:GetObject\", \"s3:ListBucket\"],\n                \"Resource\": \"arn:aws:s3:::my-bucket/*\"\n            },\n            {\n                \"Effect\": \"Allow\",\n                \"Action\": \"iam:GetUser\",\n                \"Resource\": \"arn:aws:iam::123456789012:user/example\"\n            }\n        ]\n    }\n    \n    print(\"\\nTest 3 - Multiple Statements:\")\n    print",
#     "test_case": {
#       "task": "Create a Python function that accepts an AWS IAM policy JSON string and returns a list of all Actions specified in the policy",
#       "format": "python"
#     },
#     "score": 6,
#     "reasoning": "The solution demonstrates solid AWS knowledge and good Python practices with proper error handling and type safety. However, it over-engineers the problem by using unnecessary recursion when IAM policies have a predictable, flat structure where Actions only exist in Statement objects. The incomplete code and missing edge case tests are significant issues. A more pragmatic approach would directly iterate through statements, which would be clearer and more efficient. The solution would score higher if it was complete and included comprehensive test coverage."
#   },
#   {
#     "output": "# AWS Lambda CloudFormation Template Snippet\n\nHere's a complete JSON CloudFormation template that defines an AWS Lambda function with basic execution role permissions:\n\n```json\n{\n  \"AWSTemplateFormatVersion\": \"2010-09-09\",\n  \"Description\": \"CloudFormation template for Lambda function with basic execution role\",\n  \"Resources\": {\n    \"LambdaExecutionRole\": {\n      \"Type\": \"AWS::IAM::Role\",\n      \"Properties\": {\n        \"AssumeRolePolicyDocument\": {\n          \"Version\": \"2012-10-17\",\n          \"Statement\": [\n            {\n              \"Effect\": \"Allow\",\n              \"Principal\": {\n                \"Service\": \"lambda.amazonaws.com\"\n              },\n              \"Action\": \"sts:AssumeRole\"\n            }\n          ]\n        },\n        \"ManagedPolicyArns\": [\n          \"arn:aws:iam::aws:policy/service-role/AWSLambdaBasicExecutionRole\"\n        ]\n      }\n    },\n    \"MyLambdaFunction\": {\n      \"Type\": \"AWS::Lambda::Function\",\n      \"Properties\": {\n        \"FunctionName\": \"MyBasicLambdaFunction\",\n        \"Runtime\": \"python3.11\",\n        \"Role\": {\n          \"Fn::GetAtt\": [\n            \"LambdaExecutionRole\",\n            \"Arn\"\n          ]\n        },\n        \"Handler\": \"index.lambda_handler\",\n        \"Code\": {\n          \"ZipFile\": \"def lambda_handler(event, context):\\n    return {\\n        'statusCode': 200,\\n        'body': 'Hello from Lambda!'\\n    }\"\n        },\n        \"Description\": \"Basic Lambda function with execution role\",\n        \"Timeout\": 30,\n        \"MemorySize\": 128\n      }\n    }\n  },\n  \"Outputs\": {\n    \"LambdaFunctionArn\": {\n      \"Description\": \"ARN of the Lambda function\",\n      \"Value\": {\n        \"Fn::GetAtt\": [\n          \"MyLambdaFunction\",\n          \"Arn\"\n        ]\n      }\n    },\n    \"LambdaExecutionRoleArn\": {\n      \"Description\": \"ARN of the Lambda execution role\",\n      \"Value\": {\n        \"Fn::GetAtt\": [\n          \"LambdaExecutionRole\",\n          \"Arn\"\n        ]\n      }\n    }\n  }\n}\n```\n\n## Key Components Explained:\n\n### 1. **IAM Execution Role** (`LambdaExecutionRole`)\n   - Allows Lambda service to assume the role\n   - Includes the `AWSLambdaBasicExecutionRole` managed policy for CloudWatch Logs permissions\n\n### 2. **Lambda Function** (`MyLambdaFunction`)\n   - **FunctionName**: Name of the function\n   - **Runtime**: Python 3.11 (adjustable)\n   - **Role**: References the execution role created above\n   - **Handler**: Entry point for the function\n   - **Code**: Inline Python code\n   - **Timeout**: 30 seconds\n   - **MemorySize**: 128 MB\n\n### 3. **Outputs**\n   - Returns ARNs for reference by other resources\n\n## To Deploy:\n\n```bash\naws cloudformation create-stack \\\n  --stack-name my-lambda-stack \\\n  --template-body file://template.json\n```\n\nThis template provides a secure, production-ready setup with proper IAM permissions for basic Lambda operations including CloudWatch Logs access.",
#     "test_case": {
#       "task": "Generate a JSON CloudFormation template snippet that defines an AWS Lambda function with basic execution role permissions",
#       "format": "json"
#     },
#     "score": 7,
#     "reasoning": "The solution fully addresses the core task by providing a valid, functional CloudFormation template with proper IAM execution role permissions. It demonstrates solid AWS knowledge with managed policy usage and correct resource relationships. However, the implementation is basic and lacks depth in production-readiness aspects like error handling, scalability considerations, and security hardening that would be expected in a professional code review. The template works as-is but would benefit from additional context about limitations and real-world usage patterns."
#   }
# ]
